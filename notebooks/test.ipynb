# %%
import torch as t

from nnsight import LanguageModel

model = LanguageModel("openai-community/gpt2", device_map="cuda:0", dispatch=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 5
#       1 import torch as t
#       3 from nnsight import LanguageModel
# ----> 5 model = LanguageModel("openai-community/gpt2", device_map="cuda:0", dispatch=True)
#
# File ~/.venv/lib/python3.11/site-packages/nnsight/modeling/language.py:103, in LanguageModel.__init__(self, config, tokenizer, automodel, *args, **kwargs)
#     100 self.tokenizer = tokenizer
#     101 self.repo_id: str = None
# --> 103 super().__init__(*args, **kwargs)
#     105 self.generator: Envoy[InterventionProxyType, InterventionNodeType] = (
#     106     LanguageModel.Generator()
#     107 )
#
# File ~/.venv/lib/python3.11/site-packages/nnsight/modeling/mixins/meta.py:22, in MetaMixin.__init__(self, dispatch, meta_buffers, rename, *args, **kwargs)
#      18 if isinstance(args[0], torch.nn.Module) or dispatch:
#      20     self.dispatched = True
# ---> 22     super().__init__(*args, rename=rename, **kwargs)
#      24 else:
#      26     with init_empty_weights(include_buffers=meta_buffers):
#
# File ~/.venv/lib/python3.11/site-packages/nnsight/modeling/mixins/loadable.py:14, in LoadableMixin.__init__(self, rename, *args, **kwargs)
#      10 def __init__(self, *args, rename: Optional[Dict[str,str]] = None, **kwargs) -> None:
#      12     if not isinstance(args[0], torch.nn.Module):
# ---> 14         model = self._load(*args, **kwargs)
#      16     else:
#      18         model = args[0]
#
# File ~/.venv/lib/python3.11/site-packages/nnsight/modeling/language.py:175, in LanguageModel._load(self, repo_id, tokenizer_kwargs, patch_llama_scan, **kwargs)
#     167 if (
#     168     patch_llama_scan
#     169     and isinstance(self.config, LlamaConfig)
#     170     and isinstance(self.config.rope_scaling, dict)
#     171     and "rope_type" in self.config.rope_scaling
#     172 ):
#     173     self.config.rope_scaling["rope_type"] = "llama3"
# --> 175 model = self.automodel.from_pretrained(repo_id, config=self.config, **kwargs)
#     177 return model
#
# File ~/.venv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     606 )
#
# File ~/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:315, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     313 old_dtype = torch.get_default_dtype()
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 finally:
#     317     torch.set_default_dtype(old_dtype)
#
# File ~/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:5001, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4991     if dtype_orig is not None:
#    4992         torch.set_default_dtype(dtype_orig)
#    4994     (
#    4995         model,
#    4996         missing_keys,
#    4997         unexpected_keys,
#    4998         mismatched_keys,
#    4999         offload_index,
#    5000         error_msgs,
# -> 5001     ) = cls._load_pretrained_model(
#    5002         model,
#    5003         state_dict,
#    5004         checkpoint_files,
#    5005         pretrained_model_name_or_path,
#    5006         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    5007         sharded_metadata=sharded_metadata,
#    5008         device_map=device_map,
#    5009         disk_offload_folder=offload_folder,
#    5010         offload_state_dict=offload_state_dict,
#    5011         dtype=torch_dtype,
#    5012         hf_quantizer=hf_quantizer,
#    5013         keep_in_fp32_regex=keep_in_fp32_regex,
#    5014         device_mesh=device_mesh,
#    5015         key_mapping=key_mapping,
#    5016         weights_only=weights_only,
#    5017     )
#    5018 # make sure token embedding weights are still tied if needed
#    5019 model.tie_weights()
#
# File ~/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:5417, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    5415 if device_map is not None and not is_hqq_or_quark:
#    5416     expanded_device_map = expand_device_map(device_map, expected_keys)
# -> 5417     caching_allocator_warmup(model_to_load, expanded_device_map, hf_quantizer)
#    5419 # Prepare and compatabilize arguments for serial and parallel shard loading
#    5420 args_list = [
#    5421     (
#    5422         shard_file,
#    (...)   5443     for shard_file in checkpoint_files
#    5444 ]
#
# File ~/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:6024, in caching_allocator_warmup(model, expanded_device_map, hf_quantizer)
#    6022 if device.type == "cuda":
#    6023     index = device.index if device.index is not None else torch.cuda.current_device()
# -> 6024     device_memory = torch.cuda.mem_get_info(index)[0]
#    6025     # Allow up to (max device memory - 1.2 GiB) in resource-constrained hardware configurations. Trying to reserve more
#    6026     # than that amount might sometimes lead to unnecessary cuda OOM, if the last parameter to be loaded on the device is large,
#    6027     # and the remaining reserved memory portion is smaller than the param size -> torch will then try to fully re-allocate all
#    (...)   6030     # Note that we use an absolute value instead of device proportion here, as a 8GiB device could still allocate too much
#    6031     # if using e.g. 90% of device size, while a 140GiB device would allocate too little
#    6032     byte_count = min(byte_count, max(0, int(device_memory - 1.2 * 1024**3)))
#
# File ~/.venv/lib/python3.11/site-packages/torch/cuda/memory.py:738, in mem_get_info(device)
#     736 # optional=True allows `device = torch.device('cuda')` for which device.index is None
#     737 device = _get_device_index(device, optional=True)
# --> 738 return torch.cuda.cudart().cudaMemGetInfo(device)
#
# File ~/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:396, in cudart()
#     342 def cudart():
#     343     r"""Retrieves the CUDA runtime API module.
#     344
#     345
#    (...)    394     overwrite of the output file if it already exists.
#     395     """
# --> 396     _lazy_init()
#     397     return _cudart
#
# File ~/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:319, in _lazy_init()
#     317 if "CUDA_MODULE_LOADING" not in os.environ:
#     318     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 319 torch._C._cuda_init()
#     320 # Some of the queued calls may reentrantly call _lazy_init();
#     321 # we need to just return without initializing in that case.
#     322 # However, we must not let any *other* threads in!
#     323 _tls.is_initializing = True
#
# RuntimeError: No CUDA GPUs are available

# %%
model.device
# Out:
# device(type='cpu')
